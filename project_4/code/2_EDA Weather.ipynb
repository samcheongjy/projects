# %%
import calendar
import re
import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
np.random.seed(42)

from matplotlib import rcParams
rcParams.update({'figure.autolayout':True})

pd.set_option('display.max_columns',500)
# %matplotlib inline

# %%
#Read weather dataset in csv format
df_weather=pd.read_csv('../data/weather.csv')

# %% [markdown]
# ## Weather Dataset - Initial EDA

# %%
df_weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#   Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 0    0448   1849             0      M      0.0        0.00       29.10
# 1       -      -             M      M        M        0.00       29.18
# 2    0447   1850      BR     0      M      0.0        0.00       29.38
# 3       -      -   BR HZ     M      M        M        0.00       29.44
# 4    0446   1851             0      M      0.0        0.00       29.39
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0    29.82          1.7         27      9.2
# 1    29.82          2.7         25      9.6
# 2    30.09         13.0          4     13.4
# 3    30.08         13.3          2     13.4
# 4    30.12         11.7          7     11.9

# %%
df_weather.shape
# Out:
# (2944, 22)

# %% [markdown]
# There are 22 columns and 2,944 rows in the weather dataset provided.

# %%
df_weather.describe()
# Out:
#            Station         Tmax         Tmin     DewPoint  ResultSpeed  \
# count  2944.000000  2944.000000  2944.000000  2944.000000  2944.000000
# mean      1.500000    76.166101    57.810462    53.457880     6.960666
# std       0.500085    11.461970    10.381939    10.675181     3.587527
# min       1.000000    41.000000    29.000000    22.000000     0.100000
# 25%       1.000000    69.000000    50.000000    46.000000     4.300000
# 50%       1.500000    78.000000    59.000000    54.000000     6.400000
# 75%       2.000000    85.000000    66.000000    62.000000     9.200000
# max       2.000000   104.000000    83.000000    75.000000    24.100000
#
#          ResultDir
# count  2944.000000
# mean     17.494905
# std      10.063609
# min       1.000000
# 25%       7.000000
# 50%      19.000000
# 75%      25.000000
# max      36.000000

# %% [markdown]
# There are two weather stations in the dataset which corresponds to:
# - Station 1: CHICAGO O'HARE INTERNATIONAL AIRPORT Lat: 41.995 Lon: -87.933 Elev: 662 ft. above sea level
# - Station 2: CHICAGO MIDWAY INTL ARPT Lat: 41.786 Lon: -87.752 Elev: 612 ft. above sea level

# %%
df_weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg            object
# Depart          object
# DewPoint         int64
# WetBulb         object
# Heat            object
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %% [markdown]
# Some of the columns have inappropriate data types which should be converted into proper format during cleaning.
#
# - Date - object to Datetime format,
#
# - Tavg, Depart,WetBulb, Heat, Cool, Sunrise, Sunset - object to integer format
#
# - SnowFall, PrecipTotal, StnPressure, SeaLevel, AvgSpeed - object to float format

# %%
# function to label T,M,- with 1 or 0
def count_of_t(x):
     if x == '  T':
        return 1 
     else:
        return 0
def count_of_m(x):
     if x == 'M':
        return 1
     else:
        return 0
def count_dash(x):
     if x == '-':
        return 1
     else:
        return 0
# count total number of M - T in df
def print_summary(df):
    cols = ['column', 'M', '-', 'T']
    df_summary = pd.DataFrame(columns=cols)
    idx = 0
    for col in df.columns:
        if df[col].dtype == 'object':
            total_m = df[col].apply(count_of_m).sum()
            total_dash = df[col].apply(count_dash).sum()
            total_t = df[col].apply(count_of_t).sum()
            df_summary.at[idx, cols[0]] = col
            df_summary.at[idx, cols[1]] = total_m
            df_summary.at[idx, cols[2]] = total_dash
            df_summary.at[idx, cols[3]] = total_t
        idx += 1
    return df_summary

# %%
weather_summary = print_summary(df_weather)
weather_summary
# Out:
#          column     M     -    T
# 1          Date     0     0    0
# 4          Tavg    11     0    0
# 5        Depart  1472     0    0
# 7       WetBulb     4     0    0
# 8          Heat    11     0    0
# 9          Cool    11     0    0
# 10      Sunrise     0  1472    0
# 11       Sunset     0  1472    0
# 12      CodeSum     0     0    0
# 13        Depth  1472     0    0
# 14       Water1  2944     0    0
# 15     SnowFall  1472     0   12
# 16  PrecipTotal     2     0  318
# 17  StnPressure     4     0    0
# 18     SeaLevel     9     0    0
# 21     AvgSpeed     3     0    0

# %% [markdown]
# The following have been noted from the weather dataset where 'M' represents missing values, 'T' represents trace amounts which are too small for the readings to be recorded and '-' represents blank values:
# - There are 11 M values for Tavg column.
# - There are 1472 M values for Depart column.
# - There are 4 M values for WetBulb column.
# - There are 11 M values for Heat column.
# - There are 11 M values for Cool column.
# - There are 1472 blank values for Sunrise column.
# - There are 1472 blank values for Sunset column.
# - There are 1472 M values for Depth column.
# - There are 2944 M values for Water1 column.
# - There are 1472 M values and 12 T values for SnowFall column.
# - There are 2 M values and 318 T values for PrecipTotal column.
# - There are 4 M values for StnPressure column.
# - There are 9 M values for SeaLevel column.
# - There are 3 M values for AvgSpeed column.

# %%
weather_stn1= df_weather[df_weather['Station']==1]
weather_stn2= df_weather[df_weather['Station']==2]
weather_stn1=weather_stn1.drop('Station',axis=1)
weather_stn2=weather_stn2.drop('Station',axis=1)

# %%
weather_summary_stn1 = print_summary(weather_stn1)
print('---station1----')
weather_summary_stn1
# Out:
# ---station1----
#          column     M  -    T
# 0          Date     0  0    0
# 3          Tavg     0  0    0
# 4        Depart     0  0    0
# 6       WetBulb     3  0    0
# 7          Heat     0  0    0
# 8          Cool     0  0    0
# 9       Sunrise     0  0    0
# 10       Sunset     0  0    0
# 11      CodeSum     0  0    0
# 12        Depth     0  0    0
# 13       Water1  1472  0    0
# 14     SnowFall     0  0   12
# 15  PrecipTotal     0  0  163
# 16  StnPressure     2  0    0
# 17     SeaLevel     5  0    0
# 20     AvgSpeed     0  0    0

# %% [markdown]
# The following have been noted from the weather station 1 where 'M' represents missing values, 'T' represents trace amounts which are too small for the readings to be recorded and '-' represents blank values:
# - There are 3 M values for WetBulb column.
# - There are 1472 M values for Water1 column.
# - There are 12 T values for SnowFall column.
# - There are 163 T values for PrecipTotal column.
# - There are 2 M values for StnPressure column.
# - There are 5 M values for SeaLevel column.

# %%
weather_summary_stn2 = print_summary(weather_stn2)
print('---station2----')
weather_summary_stn2
# Out:
# ---station2----
#          column     M     -    T
# 0          Date     0     0    0
# 3          Tavg    11     0    0
# 4        Depart  1472     0    0
# 6       WetBulb     1     0    0
# 7          Heat    11     0    0
# 8          Cool    11     0    0
# 9       Sunrise     0  1472    0
# 10       Sunset     0  1472    0
# 11      CodeSum     0     0    0
# 12        Depth  1472     0    0
# 13       Water1  1472     0    0
# 14     SnowFall  1472     0    0
# 15  PrecipTotal     2     0  155
# 16  StnPressure     2     0    0
# 17     SeaLevel     4     0    0
# 20     AvgSpeed     3     0    0

# %% [markdown]
# The following have been noted from the weather station 2 where 'M' represents missing values, 'T' represents trace amounts which are too small for the readings to be recorded and '-' represents blank values:
# - There are 11 M values for Tavg column.
# - There are 1472 M values for Depart column.
# - There are 1 M values for WetBulb column.
# - There are 11 M values for Heat column.
# - There are 11 M values for Cool column.
# - There are 1472 blank values for Sunrise column.
# - There are 1472 blank values for Sunset column.
# - There are 1472 M values for Depth column.
# - There are 1472 M values for Water1 column.
# - There are 1472 M values for SnowFall column.
# - There are 2 M values and 155 T values for PrecipTotal column.
# - There are 2 M values for StnPressure column.
# - There are 4 M values for SeaLevel column.
# - There are 3 M values for AvgSpeed column.

# %% [markdown]
# ## Weather Dataset - Cleaning & Imputation of Data

# %%
# 'M','-' in weather data is a missing value; convert all instances to np.nan
df_weather.replace(to_replace='M', value=np.nan, inplace=True)
df_weather.replace(to_replace='-', value=np.nan, inplace=True)

# %%
# Convert the dates to datetime format
df_weather['Date'] = pd.to_datetime(df_weather['Date'])

# %%
#Amending columns to Datetime format
df_weather['year'] = pd.DatetimeIndex(df_weather['Date']).year
df_weather['day'] = pd.DatetimeIndex(df_weather['Date']).day
df_weather['month'] = pd.DatetimeIndex(df_weather['Date']).month
df_weather['month'] = df_weather['month'].apply(lambda x: calendar.month_abbr[x])

# %%
#changing the values 11 'M' values to the straight average in 'Tavg'
new_vals = []

for i, x in enumerate(df_weather['Tavg']):
    if x != x:
        avg = (df_weather['Tmax'].loc[i] + df_weather['Tmin'].loc[i]) / 2
        new_vals.append(avg)
    else:
        new_vals.append(x)
        
df_weather['Tavg'] = new_vals
df_weather['Tavg'] = df_weather['Tavg'].astype(int)

# %%
#changing the values 11 'M' values to the formula for 'Heat'(Heating Degree Day - Base 65F)
new_vals1 = []

for i, x in enumerate(df_weather['Heat']):
    if x != x:
        if df_weather['Tavg'].loc[i] < 65:
            hdd = 65 - df_weather['Tavg'].loc[i]
            new_vals1.append(hdd)
        else:
            hdd = 0
            new_vals1.append(hdd)
    else:
        new_vals1.append(x)
        
df_weather['Heat'] = new_vals1
df_weather['Heat'] = df_weather['Heat'].astype(int)

# %%
#changing the values 11 'M' values to the formula for 'Cool'(Cooling Degree Day - Base 65F)
new_vals2 = []

for i, x in enumerate(df_weather['Cool']):
    if x != x:
        if df_weather['Tavg'].loc[i] > 65:
            hdd = df_weather['Tavg'].loc[i] - 65
            new_vals2.append(hdd)
        else:
            hdd = 0
            new_vals2.append(hdd)
    else:
        new_vals2.append(x)
        
df_weather['Cool'] = new_vals2
df_weather['Cool'] = df_weather['Cool'].astype(int)

# %%
#changing the values 4 'M' values to the formula for 'WetBulb'(Cooling Degree Day - Base 65F)
new_vals3 = []

for i, x in enumerate(df_weather['WetBulb']):
    if x != x:
        wb = df_weather['Tavg'].loc[i] - ((df_weather['Tavg'].loc[i] - df_weather['DewPoint'].loc[i])/3)
        new_vals3.append(wb)
    else:
        new_vals3.append(x)
        
df_weather['WetBulb'] = new_vals3
df_weather['WetBulb'] = df_weather['WetBulb'].astype(int)

# %%
# Drop columns with over half NANs
df_weather.drop(['Depart', 'Depth', 'Water1'], axis=1, inplace=True)

# %%
#Forward filling missing values in stnPressure/Avgspeed/SeaLevel/Sunrise/Sunset
df_weather['StnPressure'] = df_weather['StnPressure'].fillna(method='ffill').astype(float)
df_weather['AvgSpeed'] = df_weather['AvgSpeed'].fillna(method='ffill').astype(float)
df_weather['SeaLevel'] = df_weather['SeaLevel'].fillna(method='ffill').astype(float)
df_weather['Sunrise'] = df_weather['Sunrise'].fillna(method='ffill').astype(int)
df_weather['Sunset'] = df_weather['Sunset'].fillna(method='ffill').astype(int)

# %%
#Amend wrongly imputed values for Sunset
df_weather['Sunset'] = df_weather['Sunset'].replace(1860,1900)
df_weather['Sunset'] = df_weather['Sunset'].replace(1760,1800)
df_weather['Sunset'] = df_weather['Sunset'].replace(1660,1700)

# %%
#Changing the 'T' for trace rain to a quantity of 0.001, forward filling 'M' values
df_weather['PrecipTotal'] = df_weather['PrecipTotal'].apply(lambda x: 0.001 if x == '  T' else x).fillna(method='ffill').astype(float)

# %%
#Changing the 'T' for trace snowfall to a quantity of 0.01, forward filling 'M' values
df_weather['SnowFall'] = df_weather['SnowFall'].apply(lambda x: 0.01 if x == '  T' else x).fillna(method='ffill').astype(float)

# %%
# Now identify number of missing values in each column
df_weather.isnull().sum()
# Out:
# Station        0
# Date           0
# Tmax           0
# Tmin           0
# Tavg           0
# DewPoint       0
# WetBulb        0
# Heat           0
# Cool           0
# Sunrise        0
# Sunset         0
# CodeSum        0
# SnowFall       0
# PrecipTotal    0
# StnPressure    0
# SeaLevel       0
# ResultSpeed    0
# ResultDir      0
# AvgSpeed       0
# year           0
# day            0
# month          0
# dtype: int64

# %% [markdown]
# No null values are present in the weather dataset after cleaning. All 'T', 'M' & ' ' values have been imputed.

# %%
#Convert CodeSum column into a set of unique values
list_code_sum = []

def get_code_sum_elems(code_sum_string):
    global list_code_sum
    list_code_sum.extend(code_sum_string.split())
    return True

for i in df_weather['CodeSum']:
    get_code_sum_elems(i.strip())
    
set_code_sum = set(list_code_sum)
print(set_code_sum)
# Out:
# {'SN', 'FU', 'FG', 'SQ', 'GR', 'TSRA', 'VCFG', 'BCFG', 'DZ', 'VCTS', 'RA', 'BR', 'MIFG', 'TS', 'FG+', 'HZ'}

# %%
for i in set_code_sum:
    df_weather[i] = 0

# %%
#Get dummies for unique values of CodeSum column
for i, r in df_weather.iterrows():
    list_cs = r['CodeSum'].split()
    for j in list_cs:
        if j in set_code_sum:
            df_weather.loc[i,j]=1

# %%
# Drop CodeSum column
df_weather.drop(['CodeSum'], axis=1, inplace=True)

# %%
print(df_weather['TS'].value_counts())
df_weather['VCTS'].value_counts()
# Out:
# 0    2842
# 1     102
# Name: TS, dtype: int64
# 0    2925
# 1      19
# Name: VCTS, dtype: int64

# %%
# dropping columns from weather dataframe where values are all 'O's. MIFG (fog) has 3 '1' values, but we will drop it as the fog column already captures the data
drop_columns = ['BCFG','GR','VCFG','SQ', 'MIFG'] # dropping MIFG as well 
df_weather.drop(columns = drop_columns, inplace = True)

# %%
# put 1 in TS & RA columns where TSRA == 1, put 1 in TS where VCTS == 1
df_weather['TS'] = [1 if row == 1 else 0 for row in df_weather['TSRA']]
df_weather['RA'] = [1 if row == 1 else 0 for row in df_weather['TSRA']]

df_weather['TS'] = [1 if row == 1 else row for row in df_weather['VCTS']]

# %%
# checking the the result & dropping the original columns
df_weather[df_weather['VCTS'] == 1][['TS', 'VCTS', 'TSRA', 'RA']]
df_weather.drop(columns = ['VCTS', 'TSRA'], inplace = True)

# %%
df_weather.dtypes
# Out:
# Station                 int64
# Date           datetime64[ns]
# Tmax                    int64
# Tmin                    int64
# Tavg                    int64
# DewPoint                int64
# WetBulb                 int64
# Heat                    int64
# Cool                    int64
# Sunrise                 int64
# Sunset                  int64
# SnowFall              float64
# PrecipTotal           float64
# StnPressure           float64
# SeaLevel              float64
# ResultSpeed           float64
# ResultDir               int64
# AvgSpeed              float64
# year                    int64
# day                     int64
# month                  object
# SN                      int64
# FU                      int64
# FG                      int64
# DZ                      int64
# RA                      int64
# BR                      int64
# TS                      int64
# FG+                     int64
# HZ                      int64
# dtype: object

# %% [markdown]
# The data types for each columns have been appropriately classified.

# %%
# rename columns
rename_weather = {'FG+' : 'h_fog','FG' : 'fog', 'SN' : 'snow', 'FU' : 'smoke',  
                  'HZ': 'haze', 'RA': 'rain', 'DZ' : 'drizzle', 'TS': 'storm', 'BR' : 'mist'}
df_weather.rename(columns = rename_weather, inplace = True)

# %%
#impute isoweek column into df
df_weather['week']=df_weather['Date'].dt.week

# %% [markdown]
# ### Feature Engineering: Lagged weather variable for relative humidity, temperature, dewpoint, rainfall

# %%
df_weather.columns
# Out:
# Index(['Station', 'Date', 'Tmax', 'Tmin', 'Tavg', 'DewPoint', 'WetBulb',
#        'Heat', 'Cool', 'Sunrise', 'Sunset', 'SnowFall', 'PrecipTotal',
#        'StnPressure', 'SeaLevel', 'ResultSpeed', 'ResultDir', 'AvgSpeed',
#        'year', 'day', 'month', 'snow', 'smoke', 'fog', 'drizzle', 'rain',
#        'mist', 'storm', 'h_fog', 'haze', 'week'],
#       dtype='object')

# %%
# tavg: create lagged variables of 1,3 and 7 days.

df_weather['tavg_lag_1'] = df_weather['Tavg'].shift(1)
df_weather['tavg_lag_3'] = df_weather['Tavg'].shift(3)
df_weather['tavg_lag_7'] = df_weather['Tavg'].shift(7)

# rainfall: create lagged variables of 1,3 and 7 days.

df_weather['preciptotal_lag_1'] = df_weather['PrecipTotal'].shift(1)
df_weather['preciptotal_lag_3'] = df_weather['PrecipTotal'].shift(3)
df_weather['preciptotal_lag_7'] = df_weather['PrecipTotal'].shift(7)

# daylight hours. changing sunrise into HH:MM , then get the difference of hours
df_weather['sunrise_clean']=pd.to_datetime(df_weather['Sunrise'],format='%H%M')
df_weather['sunset_clean']=pd.to_datetime(df_weather['Sunset'],format='%H%M')
df_weather['DaylightHrs'] = ((df_weather['sunset_clean'] - df_weather['sunrise_clean'])/np.timedelta64(1,'h')).astype('int')

df_weather['DaylightHrs_lag_1'] = df_weather['DaylightHrs'].shift(1)
df_weather['DaylightHrs_lag_3'] = df_weather['DaylightHrs'].shift(3)
df_weather['DaylightHrs_lag_7'] = df_weather['DaylightHrs'].shift(7)

# %%
def humidity(Tf, Tdf):  
    # convert temp to celsius
    Tc=5.0/9.0*(Tf-32.0)
    
    # convert dewpoint temp to celsius
    Tdc=5.0/9.0*(Tdf-32.0)
    
    # saturation vapor pressure
    Es=6.11*10.0**(7.5*Tc/(237.7+Tc))
    
    # actual vapor pressure
    E=6.11*10.0**(7.5*Tdc/(237.7+Tdc))
    
    #relative humidity
    RH =(E/Es)*100
    return RH

# %%
# relative humidity: create lagged variables of 1,3 and 7 days.
df_weather["relhum"] = humidity(df_weather['Tavg'],df_weather['DewPoint'])

df_weather['relhum_lag_1'] = df_weather['relhum'].shift(1)
df_weather['relhum_lag_3'] = df_weather['relhum'].shift(3)
df_weather['relhum_lag_7'] = df_weather['relhum'].shift(7)

# %%
df_weather.head(20)
# Out:
#     Station       Date  Tmax  Tmin  Tavg  DewPoint  WetBulb  Heat  Cool  \
# 0         1 2007-05-01    83    50    67        51       56     0     2
# 1         2 2007-05-01    84    52    68        51       57     0     3
# 2         1 2007-05-02    59    42    51        42       47    14     0
# 3         2 2007-05-02    60    43    52        42       47    13     0
# 4         1 2007-05-03    66    46    56        40       48     9     0
# 5         2 2007-05-03    67    48    58        40       50     7     0
# 6         1 2007-05-04    66    49    58        41       50     7     0
# 7         2 2007-05-04    78    51    64        42       50     1     0
# 8         1 2007-05-05    66    53    60        38       49     5     0
# 9         2 2007-05-05    66    54    60        39       50     5     0
# 10        1 2007-05-06    68    49    59        30       46     6     0
# 11        2 2007-05-06    68    52    60        30       46     5     0
# 12        1 2007-05-07    83    47    65        41       54     0     0
# 13        2 2007-05-07    84    50    67        39       53     0     2
# 14        1 2007-05-08    82    54    68        58       62     0     3
# 15        2 2007-05-08    80    60    70        57       63     0     5
# 16        1 2007-05-09    77    61    69        59       63     0     4
# 17        2 2007-05-09    76    63    70        60       63     0     5
# 18        1 2007-05-10    84    56    70        52       60     0     5
# 19        2 2007-05-10    83    59    71        52       61     0     6
#
#     Sunrise  Sunset  SnowFall  PrecipTotal  StnPressure  SeaLevel  \
# 0       448    1849       0.0        0.000        29.10     29.82
# 1       448    1849       0.0        0.000        29.18     29.82
# 2       447    1850       0.0        0.000        29.38     30.09
# 3       447    1850       0.0        0.000        29.44     30.08
# 4       446    1851       0.0        0.000        29.39     30.12
# 5       446    1851       0.0        0.000        29.46     30.12
# 6       444    1852       0.0        0.001        29.31     30.05
# 7       444    1852       0.0        0.000        29.36     30.04
# 8       443    1853       0.0        0.001        29.40     30.10
# 9       443    1853       0.0        0.001        29.46     30.09
# 10      442    1855       0.0        0.000        29.57     30.29
# 11      442    1855       0.0        0.000        29.62     30.28
# 12      441    1856       0.0        0.001        29.38     30.12
# 13      441    1856       0.0        0.000        29.44     30.12
# 14      439    1857       0.0        0.000        29.29     30.03
# 15      439    1857       0.0        0.001        29.36     30.02
# 16      438    1858       0.0        0.130        29.21     29.94
# 17      438    1858       0.0        0.020        29.28     29.93
# 18      437    1859       0.0        0.000        29.20     29.92
# 19      437    1859       0.0        0.000        29.26     29.91
#
#     ResultSpeed  ResultDir  AvgSpeed  year  day month  snow  smoke  fog  \
# 0           1.7         27       9.2  2007    1   May     0      0    0
# 1           2.7         25       9.6  2007    1   May     0      0    0
# 2          13.0          4      13.4  2007    2   May     0      0    0
# 3          13.3          2      13.4  2007    2   May     0      0    0
# 4          11.7          7      11.9  2007    3   May     0      0    0
# 5          12.9          6      13.2  2007    3   May     0      0    0
# 6          10.4          8      10.8  2007    4   May     0      0    0
# 7          10.1          7      10.4  2007    4   May     0      0    0
# 8          11.7          7      12.0  2007    5   May     0      0    0
# 9          11.2          7      11.5  2007    5   May     0      0    0
# 10         14.4         11      15.0  2007    6   May     0      0    0
# 11         13.8         10      14.5  2007    6   May     0      0    0
# 12          8.6         18      10.5  2007    7   May     0      0    0
# 13          8.5         17       9.9  2007    7   May     0      0    0
# 14          2.7         11       5.8  2007    8   May     0      0    0
# 15          2.5          8       5.4  2007    8   May     0      0    0
# 16          3.9          9       6.2  2007    9   May     0      0    0
# 17          3.9          7       5.9  2007    9   May     0      0    0
# 18          0.7         17       4.1  2007   10   May     0      0    0
# 19          2.0          9       3.9  2007   10   May     0      0    0
#
#     drizzle  rain  mist  storm  h_fog  haze  week  tavg_lag_1  tavg_lag_3  \
# 0         0     0     0      0      0     0    18         NaN         NaN
# 1         0     0     0      0      0     0    18        67.0         NaN
# 2         0     0     1      0      0     0    18        68.0         NaN
# 3         0     0     1      0      0     1    18        51.0        67.0
# 4         0     0     0      0      0     0    18        52.0        68.0
# 5         0     0     0      0      0     1    18        56.0        51.0
# 6         0     0     0      0      0     0    18        58.0        52.0
# 7         0     0     0      0      0     0    18        58.0        56.0
# 8         0     0     0      0      0     0    18        64.0        58.0
# 9         0     0     0      0      0     0    18        60.0        58.0
# 10        0     0     0      0      0     0    18        60.0        64.0
# 11        0     0     0      0      0     0    18        59.0        60.0
# 12        0     0     0      0      0     0    19        60.0        60.0
# 13        0     0     0      0      0     0    19        65.0        59.0
# 14        0     0     1      0      0     0    19        67.0        60.0
# 15        0     0     0      0      0     1    19        68.0        65.0
# 16        0     0     1      0      0     1    19        70.0        67.0
# 17        0     0     1      0      0     1    19        69.0        68.0
# 18        0     0     1      0      0     0    19        70.0        70.0
# 19        0     0     1      0      0     1    19        70.0        69.0
#
#     tavg_lag_7  preciptotal_lag_1  preciptotal_lag_3  preciptotal_lag_7  \
# 0          NaN                NaN                NaN                NaN
# 1          NaN              0.000                NaN                NaN
# 2          NaN              0.000                NaN                NaN
# 3          NaN              0.000              0.000                NaN
# 4          NaN              0.000              0.000                NaN
# 5          NaN              0.000              0.000                NaN
# 6          NaN              0.000              0.000                NaN
# 7         67.0              0.001              0.000              0.000
# 8         68.0              0.000              0.000              0.000
# 9         51.0              0.001              0.001              0.000
# 10        52.0              0.001              0.000              0.000
# 11        56.0              0.000              0.001              0.000
# 12        58.0              0.000              0.001              0.000
# 13        58.0              0.001              0.000              0.001
# 14        64.0              0.000              0.000              0.000
# 15        60.0              0.000              0.001              0.001
# 16        60.0              0.001              0.000              0.001
# 17        59.0              0.130              0.000              0.000
# 18        60.0              0.020              0.001              0.000
# 19        65.0              0.000              0.130              0.001
#
#          sunrise_clean        sunset_clean  DaylightHrs  DaylightHrs_lag_1  \
# 0  1900-01-01 04:48:00 1900-01-01 18:49:00           14                NaN
# 1  1900-01-01 04:48:00 1900-01-01 18:49:00           14               14.0
# 2  1900-01-01 04:47:00 1900-01-01 18:50:00           14               14.0
# 3  1900-01-01 04:47:00 1900-01-01 18:50:00           14               14.0
# 4  1900-01-01 04:46:00 1900-01-01 18:51:00           14               14.0
# 5  1900-01-01 04:46:00 1900-01-01 18:51:00           14               14.0
# 6  1900-01-01 04:44:00 1900-01-01 18:52:00           14               14.0
# 7  1900-01-01 04:44:00 1900-01-01 18:52:00           14               14.0
# 8  1900-01-01 04:43:00 1900-01-01 18:53:00           14               14.0
# 9  1900-01-01 04:43:00 1900-01-01 18:53:00           14               14.0
# 10 1900-01-01 04:42:00 1900-01-01 18:55:00           14               14.0
# 11 1900-01-01 04:42:00 1900-01-01 18:55:00           14               14.0
# 12 1900-01-01 04:41:00 1900-01-01 18:56:00           14               14.0
# 13 1900-01-01 04:41:00 1900-01-01 18:56:00           14               14.0
# 14 1900-01-01 04:39:00 1900-01-01 18:57:00           14               14.0
# 15 1900-01-01 04:39:00 1900-01-01 18:57:00           14               14.0
# 16 1900-01-01 04:38:00 1900-01-01 18:58:00           14               14.0
# 17 1900-01-01 04:38:00 1900-01-01 18:58:00           14               14.0
# 18 1900-01-01 04:37:00 1900-01-01 18:59:00           14               14.0
# 19 1900-01-01 04:37:00 1900-01-01 18:59:00           14               14.0
#
#     DaylightHrs_lag_3  DaylightHrs_lag_7     relhum  relhum_lag_1  \
# 0                 NaN                NaN  56.463227           NaN
# 1                 NaN                NaN  54.553127     56.463227
# 2                 NaN                NaN  71.186199     54.553127
# 3                14.0                NaN  68.605911     71.186199
# 4                14.0                NaN  54.866267     68.605911
# 5                14.0                NaN  51.051790     54.866267
# 6                14.0                NaN  53.071802     51.051790
# 7                14.0               14.0  44.605628     53.071802
# 8                14.0               14.0  43.959460     44.605628
# 9                14.0               14.0  45.715214     43.959460
# 10               14.0               14.0  33.081503     45.715214
# 11               14.0               14.0  31.923420     33.081503
# 12               14.0               14.0  41.445014     31.923420
# 13               14.0               14.0  35.776873     41.445014
# 14               14.0               14.0  70.400498     35.776873
# 15               14.0               14.0  63.425437     70.400498
# 16               14.0               14.0  70.507937     63.425437
# 17               14.0               14.0  70.614839     70.507937
# 18               14.0               14.0  52.863306     70.614839
# 19               14.0               14.0  51.097534     52.863306
#
#     relhum_lag_3  relhum_lag_7
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3      56.463227           NaN
# 4      54.553127           NaN
# 5      71.186199           NaN
# 6      68.605911           NaN
# 7      54.866267     56.463227
# 8      51.051790     54.553127
# 9      53.071802     71.186199
# 10     44.605628     68.605911
# 11     43.959460     54.866267
# 12     45.715214     51.051790
# 13     33.081503     53.071802
# 14     31.923420     44.605628
# 15     41.445014     43.959460
# 16     35.776873     45.715214
# 17     70.400498     33.081503
# 18     63.425437     31.923420
# 19     70.507937     41.445014

# %%
#Save to csv file
df_weather.to_csv('../data/df_weather_clean.csv', encoding= 'utf-8', index=False)

# %% [markdown]
# ## Weather Dataset - EDA post-cleaning

# %%
#Set Date as index and sort by Date
df_weather2 = df_weather
df_weather2.set_index('Date', inplace=True)
df_weather2.sort_index(inplace=True)

# %%
#Amend columns to Datetime format
df_weather2['week'] = pd.DatetimeIndex(df_weather2.index).week
df_weather2['month'] = pd.DatetimeIndex(df_weather2.index).month
df_weather2['year'] = pd.DatetimeIndex(df_weather2.index).year

# %%
df_weather3 = df_weather2.loc[(df_weather2['year']==2007) | (df_weather2['year']==2009) | (df_weather2['year']==2011) | (df_weather2['year']==2013)]

# %%
#Plot Mean PrecipTotal by ISO Week Date from 2007,2009,2011,2013.
for i in ['2007','2009','2011','2013']:
    fig = plt.figure(figsize=(20,5))
    ax1 = fig.add_subplot(111)
    ax1 = sns.pointplot(x='week', y="PrecipTotal", hue="year", data=df_weather3[i].groupby(['year','week'], as_index=False)['PrecipTotal'].mean(),);
    plt.suptitle(i+' Mean PrecipTotal by week', fontsize=20)
    plt.ylabel('PrecipTotal', fontsize=15)
    plt.xlabel('ISO Week Date', fontsize=15)
    plt.ylim((0,0.7))
    plt.savefig('../image/precipperweek{}.png'.format(i));

# %% [markdown]
# Based on the above trendlines, there appears to be a spike in total precipitation during ISO Week 21, 25, 29 and 34 for all 8 years with the highest average being on ISO Week 29. There also appears to be an outlier on ISO Week 37 in 2008 where there was a sharp increase in total precipitation to almost 1.2 inches.
#
# As the West Nile Virus and mosquito breedings tend to thrive better in dry conditions compared to wet conditions, we believe that we should be focusing our efforts on ISO Week 38 to 44 (corresponding to September & October) where Mean Weekly Total Precipitation appears to be the lowest from 2007 to 2014.

# %%
#Plot Mean Tavg by ISO Week Date from 2007 to 2014
for i in ['2007','2009','2011','2013']:
    fig = plt.figure(figsize=(20,5))
    ax1 = fig.add_subplot(111)
    ax1 = sns.pointplot(x='week', y="Tavg", data=df_weather3[i].groupby(['year','week'], as_index=False)['Tavg'].mean(),color='red');
    plt.suptitle(i+' Average temperature by week', fontsize=20)
    plt.ylabel('Tavg', fontsize=15)
    plt.xlabel('ISO Week Date', fontsize=15)
    plt.ylim((40,90))
    plt.savefig('../image/tempperweek{}.png'.format(i));

# %% [markdown]
# Based on the above trendlines, the highest average temperature recorded appears to be during the period of ISO Week 25 to 35 for all 8 years with the peak being on ISO Week 27 to 28. No outliers was apparent with weekly mean Tavg rising from ISO Week 17 to 25 then sharply dropping off from ISO Week 35 to 44.
#
# As the West Nile Virus and mosquito breedings tend to thrive better in hot conditions compared to cold conditions, we believe that we should be focusing our efforts on ISO Week 25 to 35 (corresponding to Late June to August) where Mean Weekly Tavg appears to be the highest from 2007 to 2014.

# %%
#Plot Mean ResultantSpeed by ISO Week Date from 2007 to 2014
for i in ['2007','2009','2011','2013']:
    fig = plt.figure(figsize=(20,5))
    ax1 = fig.add_subplot(111)
    ax1 = sns.pointplot(x='week', y="ResultSpeed", data=df_weather3[i].groupby(['year','week'], as_index=False)['ResultSpeed'].mean(),color='green');
    plt.suptitle(i+' Average windspeed by week', fontsize=20)
    plt.ylabel('ResultSpeed', fontsize=15)
    plt.xlabel('ISO Week Date', fontsize=15)
    plt.ylim((2,12))
    plt.savefig('../image/windperweek{}.png'.format(i));

# %% [markdown]
# Based on the above trendlines, there appears to be a decrease in resultant windspeed during ISO Week 29 to 42 for all 8 years with the lowest resultant windspeed recorded being on ISO Week 33. There also appears to be an outlier on ISO Week 44 in 2011 and 2012 where there was a sharp decrease/increase in resultant windspeed correspondingly.
#
# High resultant windspeeds combined with low air temperatures contribute to the wind chill factor which is an unfavourable condition for the West Nile Virus.
#
# As the West Nile Virus and mosquito breedings tend to thrive better in hotter conditions compared to chill conditions, we believe that we should be focusing our efforts on ISO Week 29 to 42 (corresponding to Late July to October) where Mean Resultant Windspeed appears to be the lowest from 2007 to 2014.

# %%
df_weather2
# Out:
#             Station  Tmax  Tmin  Tavg  DewPoint  WetBulb  Heat  Cool  Sunrise  \
# Date
# 2007-05-01        1    83    50    67        51       56     0     2      448
# 2007-05-01        2    84    52    68        51       57     0     3      448
# 2007-05-02        1    59    42    51        42       47    14     0      447
# 2007-05-02        2    60    43    52        42       47    13     0      447
# 2007-05-03        1    66    46    56        40       48     9     0      446
# ...             ...   ...   ...   ...       ...      ...   ...   ...      ...
# 2014-10-29        2    49    40    45        34       42    20     0      620
# 2014-10-30        1    51    32    42        34       40    23     0      622
# 2014-10-30        2    53    37    45        35       42    20     0      622
# 2014-10-31        1    47    33    40        25       33    25     0      623
# 2014-10-31        2    49    34    42        29       36    23     0      623
#
#             Sunset  SnowFall  PrecipTotal  StnPressure  SeaLevel  ResultSpeed  \
# Date
# 2007-05-01    1849       0.0        0.000        29.10     29.82          1.7
# 2007-05-01    1849       0.0        0.000        29.18     29.82          2.7
# 2007-05-02    1850       0.0        0.000        29.38     30.09         13.0
# 2007-05-02    1850       0.0        0.000        29.44     30.08         13.3
# 2007-05-03    1851       0.0        0.000        29.39     30.12         11.7
# ...            ...       ...          ...          ...       ...          ...
# 2014-10-29    1650       0.0        0.000        29.42     30.07          8.5
# 2014-10-30    1649       0.0        0.000        29.34     30.09          5.1
# 2014-10-30    1649       0.0        0.001        29.41     30.10          5.9
# 2014-10-31    1647       0.1        0.030        29.49     30.20         22.6
# 2014-10-31    1647       0.1        0.040        29.54     30.20         21.7
#
#             ResultDir  AvgSpeed  year  day  month  snow  smoke  fog  drizzle  \
# Date
# 2007-05-01         27       9.2  2007    1      5     0      0    0        0
# 2007-05-01         25       9.6  2007    1      5     0      0    0        0
# 2007-05-02          4      13.4  2007    2      5     0      0    0        0
# 2007-05-02          2      13.4  2007    2      5     0      0    0        0
# 2007-05-03          7      11.9  2007    3      5     0      0    0        0
# ...               ...       ...   ...  ...    ...   ...    ...  ...      ...
# 2014-10-29         29       9.0  2014   29     10     0      0    0        0
# 2014-10-30         24       5.5  2014   30     10     0      0    0        0
# 2014-10-30         23       6.5  2014   30     10     0      0    0        0
# 2014-10-31         34      22.9  2014   31     10     1      0    0        0
# 2014-10-31         34      22.6  2014   31     10     1      0    0        0
#
#             rain  mist  storm  h_fog  haze  week  tavg_lag_1  tavg_lag_3  \
# Date
# 2007-05-01     0     0      0      0     0    18         NaN         NaN
# 2007-05-01     0     0      0      0     0    18        67.0         NaN
# 2007-05-02     0     1      0      0     0    18        68.0         NaN
# 2007-05-02     0     1      0      0     1    18        51.0        67.0
# 2007-05-03     0     0      0      0     0    18        52.0        68.0
# ...          ...   ...    ...    ...   ...   ...         ...         ...
# 2014-10-29     0     0      0      0     0    44        43.0        57.0
# 2014-10-30     0     0      0      0     0    44        45.0        57.0
# 2014-10-30     0     0      0      0     0    44        42.0        43.0
# 2014-10-31     0     0      0      0     0    44        45.0        45.0
# 2014-10-31     0     1      0      0     0    44        40.0        42.0
#
#             tavg_lag_7  preciptotal_lag_1  preciptotal_lag_3  \
# Date
# 2007-05-01         NaN                NaN                NaN
# 2007-05-01         NaN              0.000                NaN
# 2007-05-02         NaN              0.000                NaN
# 2007-05-02         NaN              0.000              0.000
# 2007-05-03         NaN              0.000              0.000
# ...                ...                ...                ...
# 2014-10-29        53.0              0.000              0.001
# 2014-10-30        55.0              0.000              0.030
# 2014-10-30        64.0              0.000              0.000
# 2014-10-31        67.0              0.001              0.000
# 2014-10-31        57.0              0.030              0.000
#
#             preciptotal_lag_7       sunrise_clean        sunset_clean  \
# Date
# 2007-05-01                NaN 1900-01-01 04:48:00 1900-01-01 18:49:00
# 2007-05-01                NaN 1900-01-01 04:48:00 1900-01-01 18:49:00
# 2007-05-02                NaN 1900-01-01 04:47:00 1900-01-01 18:50:00
# 2007-05-02                NaN 1900-01-01 04:47:00 1900-01-01 18:50:00
# 2007-05-03                NaN 1900-01-01 04:46:00 1900-01-01 18:51:00
# ...                       ...                 ...                 ...
# 2014-10-29              0.000 1900-01-01 06:20:00 1900-01-01 16:50:00
# 2014-10-30              0.000 1900-01-01 06:22:00 1900-01-01 16:49:00
# 2014-10-30              0.000 1900-01-01 06:22:00 1900-01-01 16:49:00
# 2014-10-31              0.020 1900-01-01 06:23:00 1900-01-01 16:47:00
# 2014-10-31              0.001 1900-01-01 06:23:00 1900-01-01 16:47:00
#
#             DaylightHrs  DaylightHrs_lag_1  DaylightHrs_lag_3  \
# Date
# 2007-05-01           14                NaN                NaN
# 2007-05-01           14               14.0                NaN
# 2007-05-02           14               14.0                NaN
# 2007-05-02           14               14.0               14.0
# 2007-05-03           14               14.0               14.0
# ...                 ...                ...                ...
# 2014-10-29           10               10.0               10.0
# 2014-10-30           10               10.0               10.0
# 2014-10-30           10               10.0               10.0
# 2014-10-31           10               10.0               10.0
# 2014-10-31           10               10.0               10.0
#
#             DaylightHrs_lag_7     relhum  relhum_lag_1  relhum_lag_3  \
# Date
# 2007-05-01                NaN  56.463227           NaN           NaN
# 2007-05-01                NaN  54.553127     56.463227           NaN
# 2007-05-02                NaN  71.186199     54.553127           NaN
# 2007-05-02                NaN  68.605911     71.186199     56.463227
# 2007-05-03                NaN  54.866267     68.605911     54.553127
# ...                       ...        ...           ...           ...
# 2014-10-29               10.0  65.123306     64.865376     48.942354
# 2014-10-30               10.0  73.047853     65.123306     52.920463
# 2014-10-30               10.0  67.773903     73.047853     64.865376
# 2014-10-31               10.0  54.650803     67.773903     65.123306
# 2014-10-31               10.0  59.669686     54.650803     73.047853
#
#             relhum_lag_7
# Date
# 2007-05-01           NaN
# 2007-05-01           NaN
# 2007-05-02           NaN
# 2007-05-02           NaN
# 2007-05-03           NaN
# ...                  ...
# 2014-10-29     44.577025
# 2014-10-30     43.140591
# 2014-10-30     62.660500
# 2014-10-31     58.586825
# 2014-10-31     48.942354
#
# [2944 rows x 46 columns]

# %%
df_weather3['day_min']=[(df_weather3['sunset_clean'][i]-df_weather3['sunrise_clean'][i]).total_seconds()/60 for i in df_weather3['Sunrise']]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fig = plt.figure(figsize=(13,9))
ax1 = fig.add_subplot(111)
ax1 = sns.pointplot(x='week', y="day_min", hue="year", data=df_weather3.groupby(['year','week'], as_index=False)['day_min'].mean(),);
